# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
data = pd.read_csv('../data/musteriler.csv')
data
# Out:
#       No Cinsiyet  Yas  Hacim  Maas
# 0      1        K   60  69900  6325
# 1      2        K   30  79000  5200
# 2      3        E   52  85500  7825
# 3      4        E   57  17100  8375
# 4      5        E   55   5500  5450
# ..   ...      ...  ...    ...   ...
# 195  196        E   22  96600  7900
# 196  197        E   39  83700  7675
# 197  198        K   25  34000  4000
# 198  199        K   30  42000  5500
# 199  200        K   23  47600  4150
#
# [200 rows x 5 columns]

# %%
from sklearn.cluster import KMeans

# Selecting the features for clustering
X = data.iloc[:,3:].values
# Fitting K-Means to the dataset
kmeans = KMeans(n_clusters=4, init='k-means++')
kmeans.fit(X)

print(kmeans.cluster_centers_)
# Out:
# [[ 45534.32835821   5216.04477612]
#  [123163.15789474   7994.73684211]
#  [ 82342.30769231   6821.63461538]
#  [ 16958.06451613   5399.59677419]]

# %%
example_predit = np.array([[67900, 4650]])  # Example input for prediction
predicted_cluster = kmeans.predict(example_predit)
print(f'The predicted cluster for the input {example_predit} is: {predicted_cluster[0]}')
# Out:
# The predicted cluster for the input [[67900  4650]] is: 2

# %%
sonuclar = []
for i in range(1,10):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=123)
    kmeans.fit(X)
    sonuclar.append(kmeans.inertia_)

plt.plot(range(1,10),sonuclar)
