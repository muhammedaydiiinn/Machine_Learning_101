# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df = pd.read_csv('../../../../data/odev_tennis.csv')


windy = df.iloc[:,3:4].values
windy

play = df.iloc[:,-1:].values
play

from sklearn import preprocessing

veriler2 = df.apply(preprocessing.LabelEncoder().fit_transform)


outlook = veriler2.iloc[:,:1] 


ohe = preprocessing.OneHotEncoder()
outlook = ohe.fit_transform(outlook).toarray()
outlook


havaDurumu = pd.DataFrame(data=outlook, index=range(14), columns=['overcast', 'rainy', 'sunny'])
data = pd.concat([havaDurumu, df.iloc[:, 1:3]], axis=1)
data = pd.concat([veriler2.iloc[:,-2:],data], axis=1)


from sklearn.model_selection import train_test_split
x_train ,x_test,y_train,y_test = train_test_split(data.iloc[:,:-1] ,data.iloc[:,-1:],test_size=0.33,random_state=0)


from sklearn.linear_model import LinearRegression
regressor = LinearRegression()


regressor.fit(x_train,y_train)

y_pred = regressor.predict(x_test)
print(y_pred)

import statsmodels.api as sm

# Sabit terim ekleme
X = np.append(arr=np.ones((14, 1)).astype(int), values=data.iloc[:, :-1], axis=1)

# Bağımsız değişkenleri alma ve float türüne dönüştürme
X_1 = data.iloc[:, [0, 1, 2, 3, 4, 5]].values
X_1 = np.array(X_1, dtype=float)

# Model oluşturma ve fit etme
model = sm.OLS(data.iloc[:, -1:], X_1).fit()
model.summary()

data = data.iloc[:,1:]


# Sabit terim ekleme
X = np.append(arr=np.ones((14, 1)).astype(int), values=data.iloc[:, :-1], axis=1)

# Bağımsız değişkenleri alma ve float türüne dönüştürme
X_1 = data.iloc[:, [0, 1, 2, 3, 4]].values
X_1 = np.array(X_1, dtype=float)

# Model oluşturma ve fit etme
model = sm.OLS(data.iloc[:, -1:], X_1).fit()
model.summary()



x_train = x_train.iloc[:,1:]
x_test = x_test.iloc[:,1:]

regressor = LinearRegression()
regressor.fit(x_train,y_train)
y_pred1 = regressor.predict(x_test)
